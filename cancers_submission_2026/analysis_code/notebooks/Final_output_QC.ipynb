# %% [markdown]
# # Final output cross-check
#
# Authoritative final rerun; seed 20260722.

# %%
from pathlib import Path
import json, pandas as pd
ROOT=Path(r'E:\Open PBTA')
OUT=ROOT/'FINAL MANUSCRIPT 260722'/'8. Final rerun outputs'
ann=pd.read_csv(OUT/'01_tables'/'sample_master_annotation_final.tsv',sep='\t')
assert ann.shape[0]==349
assert ann.ecotype.value_counts().to_dict()=={'Myeloid-dominant':160,'Lymphocyte-inflamed':111,'Immune-desert':78}
for f in ['Figure4.png','Figure7C.png','FigureS5.png','FigureS_adjusted_DEG.png']:
 assert (OUT/'02_figures'/f).exists(), f
print('All final checks passed')
# Out:
# All final checks passed
