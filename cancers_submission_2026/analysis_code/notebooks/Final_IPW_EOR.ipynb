# %% [markdown]
# # IPW and EOR final sensitivity analyses
#
# Authoritative final rerun; seed 20260722.

# %%
from pathlib import Path
import json, pandas as pd
ROOT=Path(r'E:\Open PBTA')
OUT=ROOT/'FINAL MANUSCRIPT 260722'/'8. Final rerun outputs'
ipw=json.loads((OUT/'01_tables'/'IPW_summary_final.json').read_text())
eor=json.loads((OUT/'01_tables'/'EOR_summary_final.json').read_text())
cox=pd.read_csv(OUT/'01_tables'/'Cox_naive_vs_IPW_final.tsv',sep='\t')
assert ipw['n_observed']==251 and eor['n_EOR_subset']==130
print(ipw)
print(eor)
display(cox)
# Out:
# {'n_total': 349, 'n_observed': 251, 'missingness_percent': 28.08022922636103, 'weight_raw_min': 0.757466055252031, 'weight_raw_max': 7.682362815665522, 'weight_trim_limits': [0.7597333821190997, 5.786178921336161], 'n_abs_SMD_gt_0.1_before': 5, 'n_abs_SMD_gt_0.1_after': 4, 'max_abs_SMD_after': 0.34839377120377074, 'interpretation': 'IPW addresses missingness conditional on measured covariates (MAR-type assumption); it does not establish robustness to MNAR.'}
# {'n_full': 251, 'n_EOR_subset': 130, 'events_full': 208, 'events_EOR_subset': 96, 'likelihood_ratio_chi2': 0.7198420958480938, 'likelihood_ratio_df': 2, 'likelihood_ratio_p': 0.6977314112398333}
#                        term  coef_naive  HR_naive  CI_low_naive  \
# 0  ecotype_Myeloid-dominant    0.273788  1.314935      0.947839
# 1     ecotype_Immune-desert    0.596071  1.814973      1.219622
# 2      cohort_group_DMG_K27    1.100030  3.004257      2.139920
# 3      cohort_group_DHG_G34    0.154904  1.167546      0.601639
# ...
