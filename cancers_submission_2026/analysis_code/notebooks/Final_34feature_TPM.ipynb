# %% [markdown]
# # 34-feature TPM rerun
#
# Authoritative final rerun; seed 20260722.

# %%
from pathlib import Path
import json, pandas as pd
ROOT=Path(r'E:\Open PBTA')
OUT=ROOT/'FINAL MANUSCRIPT 260722'/'8. Final rerun outputs'
s=json.loads((OUT/'01_tables'/'TPM34_summary.json').read_text())
p=pd.read_csv(OUT/'01_tables'/'PERMANOVA_34feature_final.tsv',sep='\t')
assert s['n_features']==34 and s['canonical_counts']=={'Lymphocyte-inflamed':111,'Myeloid-dominant':160,'Immune-desert':78}
print(s)
display(p)
# Out:
# {'n': 349, 'n_features': 34, 'n_quantiseq': 10, 'n_ssgsea': 24, 'consensus_bootstrap': 500, 'subsample_fraction': 0.8, 'ARI_vs_canonical': 0.5541281521010023, 'NMI_vs_canonical': 0.5318449524958995, 'per_sample_agreement': 0.833810888252149, 'cluster_mapping': {'0': 'Lymphocyte-inflamed', '1': 'Myeloid-dominant', '2': 'Immune-desert'}, 'canonical_counts': {'Lymphocyte-inflamed': 111, 'Myeloid-dominant': 160, 'Immune-desert': 78}, 'TPM34_counts': {'Lymphocyte-inflamed': 103, 'Myeloid-dominant': 184, 'Immune-desert': 62}}
#      n  n_features                       order                        term  \
# 0  258          34  molecular_group + location             molecular_group
# 1  258          34  molecular_group + location  location | molecular_group
# 2  258          34  molecular_group + location                    Residual
# 3  258          34  molecular_group + location                       Total
# 4  258          34  location + molecular_group                    location
# ...
