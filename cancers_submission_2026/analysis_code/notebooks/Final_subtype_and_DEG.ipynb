# %% [markdown]
# # Subtype calibration and adjusted DEG
#
# Authoritative final rerun; seed 20260722.

# %%
from pathlib import Path
import json, pandas as pd
ROOT=Path(r'E:\Open PBTA')
OUT=ROOT/'FINAL MANUSCRIPT 260722'/'8. Final rerun outputs'
inter=json.loads((OUT/'01_tables'/'ecotype_subtype_interaction_final.json').read_text())
deg=json.loads((OUT/'01_tables'/'adjusted_DEG_summary.json').read_text())
sub=pd.read_csv(OUT/'01_tables'/'subtype_stratified_Cox_final.tsv',sep='\t')
assert deg['n_samples']==349 and deg['n_genes_tested']==18586
print(inter)
print(deg)
display(sub)
# Out:
# {'n': 251, 'events': 208, 'chi2': 6.2033557594604645, 'df': 6, 'p': 0.40080005922309797, 'interpretation': 'No interaction was detected; this is not evidence that effects generalize across subtypes.'}
# {'n_samples': 349, 'n_genes_tested': 18586, 'model': 'log2(TPM+1) ~ ecotype + molecular_group', 'contrasts': {'Lymphocyte_inflamed_vs_Immune_desert': {'q05_FCgt1_up': 3816, 'q05_FClt_minus1_down': 247}, 'Myeloid_dominant_vs_Immune_desert': {'q05_FCgt1_up': 444, 'q05_FClt_minus1_down': 72}, 'Lymphocyte_inflamed_vs_Myeloid_dominant': {'q05_FCgt1_up': 843, 'q05_FClt_minus1_down': 113}}}
#   cohort_group   n  events        HR    CI_low    CI_high         p
# 0      DHG_G34  10       8  1.026354  0.084016  12.538079  0.983747
# 1      DMG_K27  68      63  1.773020  1.038756   3.026310  0.035786
# 2          IHG  10       4  1.927734  0.076577  48.528128  0.690049
# 3      pHGG_WT  47      32  2.051242  1.009785   4.166822  0.046934
